# %% [markdown]
# <a href="https://colab.research.google.com/github/shahzaib1233/shahzaib-imtiaz-labs/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI

client = OpenAI(api_key="", base_url="https://api.deepseek.com")

# Chat loop
while True:

    user_input = input("You: ")

    # Exit condition
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    # Send input to DeepSeek
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[{"role": "user", "content": user_input}]
    )

    # Print response
    print("Chatbot:", response.choices[0].message.content)
# Out:
# You: gy
# Chatbot: 你好！我是 DeepSeek，很高兴见到你！😊
#
# 看到你发来“gy”，我不太确定你想表达什么。可能有以下几种情况：
#
# 1. **拼音缩写**：比如“工业”、“公益”、“光影”等词的拼音首字母
# 2. **网络用语**：某些聊天场景中的特定含义
# 3. **打字错误**：可能本来想输入其他内容
# 4. **问候语**：如果是“good evening”的缩写，那晚上好呀！🌙
#
# 能告诉我你想聊些什么吗？或者补充一下“gy”的具体含义？我会很乐意帮你解答问题、聊天或者提供帮助的！无论是学习、工作、生活上的问题，还是想找个朋友聊聊天，我都在这里等着你～ 😊
# You: plz reply in englihs
# Chatbot: Got it! I'll reply in English from now on. What would you like to talk about or ask?
# You: what is your name and my name si shahzaib
# Chatbot: Nice to meet you, Shahzaib! 😊
#
# My name is **DeepSeek**—I'm an AI assistant created by the DeepSeek company (深度求索). I'm here to help you with questions, tasks, ideas, or just to chat.
#
# What can I do for you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4894/1657570805.py in <cell line: 0>()
#       6 while True:
#       7
# ----> 8     user_input = input("You: ")
#       9
#      10     # Exit condition
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
